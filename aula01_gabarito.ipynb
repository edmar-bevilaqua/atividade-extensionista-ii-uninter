# %% [markdown]
# # Gabarito: Aula 01
# ### Desafio: Cartão de Visita
#
# > Este arquivo contém as soluções dos desafios. Tente resolver sozinho antes de consultar!

# %% [markdown]
# ---
# ## Solução do Desafio: Cartão de Visita

# %%
# Solução 1: Cartão com asteriscos
print("****************************")
print("* *")
print("* EDMAR BEVILAQUA *")
print("* 'Amo programar Python!' *")
print("* *")
print("****************************")

# %%
# Solução 2: Cartão com bordas diferentes
print("╔══════════════════════════╗")
print("║ ║")
print("║ 🐍 PYTHONISTA JR 🐍 ║")
print("║ MARIA DA SILVA ║")
print("║ Estudante de Tecnologia ║")
print("║ ║")
print("╚══════════════════════════╝")

# %%
# Solução 3: Arte ASCII mais elaborada
print(" _____________________________ ")
print(" / \ ")
print("| *** JOÃO DA SILVA *** |")
print("| 'O código é minha arte!' |")
print("| |")
print("| Futuro dev full-stack |")
print(" \\_____________________________/ ")
